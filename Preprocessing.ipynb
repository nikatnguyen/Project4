# %%
# Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
from sklearn.datasets import make_circles

# %%
#Read CSV file into pandas df
df = pd.read_csv("ObesityDataSet.csv")
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB

# %%
#Transform NObeyesdad Column with get_dummies
obesity_dummies = pd.get_dummies(df["NObeyesdad"])
obesity_dummies.tail()
# Out:
#       Insufficient_Weight  Normal_Weight  Obesity_Type_I  Obesity_Type_II  \
# 2106                    0              0               0                0
# 2107                    0              0               0                0
# 2108                    0              0               0                0
# 2109                    0              0               0                0
# 2110                    0              0               0                0
#
#       Obesity_Type_III  Overweight_Level_I  Overweight_Level_II
# 2106                 1                   0                    0
# 2107                 1                   0                    0
# 2108                 1                   0                    0
# 2109                 1                   0                    0
# 2110                 1                   0                    0

# %%
df = pd.concat([df, obesity_dummies], axis=1)

# Drop the original NObeyesdad column
df = df.drop(columns=["NObeyesdad"])

# Display the DataFrame
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  ...  TUE        CALC                 MTRANS  \
# 0  3.0  Sometimes    no  ...  1.0          no  Public_Transportation
# 1  3.0  Sometimes   yes  ...  0.0   Sometimes  Public_Transportation
# 2  3.0  Sometimes    no  ...  1.0  Frequently  Public_Transportation
# 3  3.0  Sometimes    no  ...  0.0  Frequently                Walking
# 4  1.0  Sometimes    no  ...  0.0   Sometimes  Public_Transportation
#
#    Insufficient_Weight Normal_Weight Obesity_Type_I  Obesity_Type_II  \
# 0                    0             1              0                0
# 1                    0             1              0                0
# 2                    0             1              0                0
# 3                    0             0              0                0
# 4                    0             0              0                0
#
#    Obesity_Type_III  Overweight_Level_I  Overweight_Level_II
# 0                 0                   0                    0
# 1                 0                   0                    0
# 2                 0                   0                    0
# 3                 0                   1                    0
# 4                 0                   0                    1
#
# [5 rows x 23 columns]

# %%
#Do the same with other non numeric columns
gender_dummies = pd.get_dummies(df["Gender"])
gender_dummies.tail()
# Out:
#       Female  Male
# 2106       1     0
# 2107       1     0
# 2108       1     0
# 2109       1     0
# 2110       1     0

# %%
df = pd.concat([df, gender_dummies], axis=1)

# Drop the original column
df = df.drop(columns=["Gender"])

# %%
family_dummies = pd.get_dummies(df["family_history_with_overweight"])
family_dummies.tail()
# Out:
#       no  yes
# 2106   0    1
# 2107   0    1
# 2108   0    1
# 2109   0    1
# 2110   0    1

# %%
df = pd.concat([df, family_dummies], axis=1)

# Drop the original column
df = df.drop(columns=["family_history_with_overweight"])

# %%
favc_dummies = pd.get_dummies(df["FAVC"])
favc_dummies.tail()
# Out:
#       no  yes
# 2106   0    1
# 2107   0    1
# 2108   0    1
# 2109   0    1
# 2110   0    1

# %%
df = pd.concat([df, favc_dummies], axis=1)

# Drop the original column
df = df.drop(columns=["FAVC"])

# %%
caec_dummies = pd.get_dummies(df["CAEC"])
caec_dummies.tail()
# Out:
#       Always  Frequently  Sometimes  no
# 2106       0           0          1   0
# 2107       0           0          1   0
# 2108       0           0          1   0
# 2109       0           0          1   0
# 2110       0           0          1   0

# %%
df = pd.concat([df, caec_dummies], axis=1)

# Drop the original column
df = df.drop(columns=["CAEC"])

# %%
smoke_dummies = pd.get_dummies(df["SMOKE"])
smoke_dummies.tail()
# Out:
#       no  yes
# 2106   1    0
# 2107   1    0
# 2108   1    0
# 2109   1    0
# 2110   1    0

# %%
df = pd.concat([df, smoke_dummies], axis=1)

# Drop the original column
df = df.drop(columns=["SMOKE"])

# %%
scc_dummies = pd.get_dummies(df["SCC"])
scc_dummies.tail()
# Out:
#       no  yes
# 2106   1    0
# 2107   1    0
# 2108   1    0
# 2109   1    0
# 2110   1    0

# %%
df = pd.concat([df, scc_dummies], axis=1)

# Drop the original column
df = df.drop(columns=["SCC"])

# %%
calc_dummies = pd.get_dummies(df["CALC"])
calc_dummies.tail()
# Out:
#       Always  Frequently  Sometimes  no
# 2106       0           0          1   0
# 2107       0           0          1   0
# 2108       0           0          1   0
# 2109       0           0          1   0
# 2110       0           0          1   0

# %%
df = pd.concat([df, calc_dummies], axis=1)

# Drop the original column
df = df.drop(columns=["CALC"])

# %%
transit_dummies = pd.get_dummies(df["MTRANS"])
transit_dummies.tail()
# Out:
#       Automobile  Bike  Motorbike  Public_Transportation  Walking
# 2106           0     0          0                      1        0
# 2107           0     0          0                      1        0
# 2108           0     0          0                      1        0
# 2109           0     0          0                      1        0
# 2110           0     0          0                      1        0

# %%
df = pd.concat([df, transit_dummies], axis=1)

# Drop the original column
df = df.drop(columns=["MTRANS"])

# %%
df.head()
# Out:
#     Age  Height  Weight  FCVC  NCP  CH2O  FAF  TUE  Insufficient_Weight  \
# 0  21.0    1.62    64.0   2.0  3.0   2.0  0.0  1.0                    0
# 1  21.0    1.52    56.0   3.0  3.0   3.0  3.0  0.0                    0
# 2  23.0    1.80    77.0   2.0  3.0   2.0  2.0  1.0                    0
# 3  27.0    1.80    87.0   3.0  3.0   2.0  2.0  0.0                    0
# 4  22.0    1.78    89.8   2.0  1.0   2.0  0.0  0.0                    0
#
#    Normal_Weight  ...  yes  Always  Frequently  Sometimes  no  Automobile  \
# 0              1  ...    0       0           0          0   1           0
# 1              1  ...    1       0           0          1   0           0
# 2              1  ...    0       0           1          0   0           0
# 3              0  ...    0       0           1          0   0           0
# 4              0  ...    0       0           0          1   0           0
#
#    Bike  Motorbike  Public_Transportation  Walking
# 0     0          0                      1        0
# 1     0          0                      1        0
# 2     0          0                      1        0
# 3     0          0                      0        1
# 4     0          0                      1        0
#
# [5 rows x 38 columns]

# %%
df.to_csv('clean_df.csv', index=False)
