# %% [markdown]
# <a href="https://colab.research.google.com/github/nikatnguyen/Project4/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
#Import dataset
df = pd.read_csv('https://raw.githubusercontent.com/nikatnguyen/Project4/main/Resources/ObesityDataSet.csv')
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
#Drop any unnecessary columns
df = df.drop(columns = ['NCP', 'SCC', 'TUE'])
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#         CAEC SMOKE  CH2O  FAF        CALC                 MTRANS  \
# 0  Sometimes    no   2.0  0.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  3.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0  2.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0  2.0  Frequently                Walking
# 4  Sometimes    no   2.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
#Convert all strings to numeric (dummies)
df = pd.get_dummies(df, columns = ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'CALC', 'MTRANS'], drop_first = True)
df.head()
# Out:
#     Age  Height  Weight  FCVC  CH2O  FAF           NObeyesdad  Gender_Male  \
# 0  21.0    1.62    64.0   2.0   2.0  0.0        Normal_Weight        False
# 1  21.0    1.52    56.0   3.0   3.0  3.0        Normal_Weight        False
# 2  23.0    1.80    77.0   2.0   2.0  2.0        Normal_Weight         True
# 3  27.0    1.80    87.0   3.0   2.0  2.0   Overweight_Level_I         True
# 4  22.0    1.78    89.8   2.0   2.0  0.0  Overweight_Level_II         True
#
#    family_history_with_overweight_yes  FAVC_yes  ...  CAEC_Sometimes  CAEC_no  \
# 0                                True     False  ...            True    False
# 1                                True     False  ...            True    False
# 2                                True     False  ...            True    False
# 3                               False     False  ...            True    False
# 4                               False     False  ...            True    False
#
# ...

# %%
#Save to sql file for use
#Create engine
engine = create_engine('sqlite:///obesity_dummies.db')

df.to_sql('obesity_dummies_df.sql', con=engine, index=False, if_exists='replace')
# Out:
# 2111
